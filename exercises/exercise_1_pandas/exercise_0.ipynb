# %% [markdown]
# # exercise 0

# %%
import pandas as pd

df = pd.read_excel("data/riket2023_åk9_np.xlsx")
df
# Out:
#                                            Unnamed: 0       Unnamed: 1  \
# 0                                                 NaN              NaN
# 1   Grundskolan - Resultat nationella prov årskurs...              NaN
# 2                                            Engelska              NaN
# 3                                 Valt läsår: 2022/23              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7                                               Riket  Typ av huvudman
# 8                                               Riket         Samtliga
# 9                                               Riket         Kommunal
# 10                                              Riket          Enskild
# 11                                              Riket       Skolverket
#
# ...

# %% [markdown]
# ***b) rename the columns***

# %%
df_rename = df.tail(4).rename(
    {
        "Unnamed: 0": "Plats",
        "Unnamed: 1": "Huvudman",
        "Unnamed: 2": "Totalt (A-F)",
        "Unnamed: 3": "Flickor (A-F)",
        "Unnamed: 4": "Pojkar (A-F)",
        "Unnamed: 5": "Totalt (A-E)",
        "Unnamed: 6": "Flickor (A-E)",
        "Unnamed: 7": "Pojkar (A-E)",
        "Unnamed: 8": "Totalt (poäng)",
        "Unnamed: 9": "Flickor (Poäng)",
        "Unnamed: 10": "Pojkar (poäng)"
    },
    axis=1,
)
df_rename
# Out:
#     Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga       106941         51864        55077           97
# 9   Riket    Kommunal        84310         40675        43635         96.6
# 10  Riket     Enskild        22582         11165        11417         98.7
# 11  Riket  Skolverket           49            24           25          100
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           97.1           97           15.7            15.8           15.7
# 9           96.6         96.6           15.4            15.5           15.4
# 10          98.8         98.7           16.9              17           16.8
# 11           100          100           18.5            18.9           18.2

# %%
df_rename.head()
# Out:
#     Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga       106941         51864        55077           97
# 9   Riket    Kommunal        84310         40675        43635         96.6
# 10  Riket     Enskild        22582         11165        11417         98.7
# 11  Riket  Skolverket           49            24           25          100
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           97.1           97           15.7            15.8           15.7
# 9           96.6         96.6           15.4            15.5           15.4
# 10          98.8         98.7           16.9              17           16.8
# 11           100          100           18.5            18.9           18.2

# %% [markdown]
# ***c) exploring data***

# %%
df_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 8 to 11
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plats            4 non-null      object
#  1   Huvudman         4 non-null      object
#  2   Totalt (A-F)     4 non-null      object
#  3   Flickor (A-F)    4 non-null      object
#  4   Pojkar (A-F)     4 non-null      object
#  5   Totalt (A-E)     4 non-null      object
#  6   Flickor (A-E)    4 non-null      object
#  7   Pojkar (A-E)     4 non-null      object
#  8   Totalt (poäng)   4 non-null      object
#  9   Flickor (Poäng)  4 non-null      object
#  10  Pojkar (poäng)   4 non-null      object
# dtypes: object(11)
# memory usage: 484.0+ bytes

# %%
df_rename.value_counts()
# Out:
# Plats  Huvudman    Totalt (A-F)  Flickor (A-F)  Pojkar (A-F)  Totalt (A-E)  Flickor (A-E)  Pojkar (A-E)  Totalt (poäng)  Flickor (Poäng)  Pojkar (poäng)
# Riket  Enskild     22582         11165          11417         98.7          98.8           98.7          16.9            17.0             16.8              1
#        Kommunal    84310         40675          43635         96.6          96.6           96.6          15.4            15.5             15.4              1
#        Samtliga    106941        51864          55077         97.0          97.1           97.0          15.7            15.8             15.7              1
#        Skolverket  49            24             25            100.0         100.0          100.0         18.5            18.9             18.2              1
# Name: count, dtype: int64

# %%
df_rename["Huvudman"].value_counts()
# Out:
# Huvudman
# Samtliga      1
# Kommunal      1
# Enskild       1
# Skolverket    1
# Name: count, dtype: int64

# %%
df_rename["Flickor (Poäng)"].value_counts()
# Out:
# Flickor (Poäng)
# 15.8    1
# 15.5    1
# 17      1
# 18.9    1
# Name: count, dtype: int64

# %%
df_rename["Flickor (Poäng)"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4 entries, 8 to 11
# Series name: Flickor (Poäng)
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      object
# dtypes: object(1)
# memory usage: 164.0+ bytes

# %%
df_rename.columns
# Out:
# Index(['Plats', 'Huvudman', 'Totalt (A-F)', 'Flickor (A-F)', 'Pojkar (A-F)',
#        'Totalt (A-E)', 'Flickor (A-E)', 'Pojkar (A-E)', 'Totalt (poäng)',
#        'Flickor (Poäng)', 'Pojkar (poäng)'],
#       dtype='object')

# %%
df_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 8 to 11
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plats            4 non-null      object
#  1   Huvudman         4 non-null      object
#  2   Totalt (A-F)     4 non-null      object
#  3   Flickor (A-F)    4 non-null      object
#  4   Pojkar (A-F)     4 non-null      object
#  5   Totalt (A-E)     4 non-null      object
#  6   Flickor (A-E)    4 non-null      object
#  7   Pojkar (A-E)     4 non-null      object
#  8   Totalt (poäng)   4 non-null      object
#  9   Flickor (Poäng)  4 non-null      object
#  10  Pojkar (poäng)   4 non-null      object
# dtypes: object(11)
# memory usage: 484.0+ bytes

# %%
data_file = "data/riket2023_åk9_np.xlsx"

df_math = pd.read_excel(data_file, sheet_name= "Matematik")
df_math
# Out:
#                                            Unnamed: 0       Unnamed: 1  \
# 0                                                 NaN              NaN
# 1   Grundskolan - Resultat nationella prov årskurs...              NaN
# 2                                           Matematik              NaN
# 3                                 Valt läsår: 2022/23              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7                                               Riket  Typ av huvudman
# 8                                               Riket         Samtliga
# 9                                               Riket         Kommunal
# 10                                              Riket          Enskild
# 11                                              Riket       Skolverket
#
# ...

# %%
df_math_rename = df_math.tail(4).rename(
    {
        "Unnamed: 0": "Plats",
        "Unnamed: 1": "Huvudman",
        "Unnamed: 2": "Totalt (A-F)",
        "Unnamed: 3": "Flickor (A-F)",
        "Unnamed: 4": "Pojkar (A-F)",
        "Unnamed: 5": "Totalt (A-E)",
        "Unnamed: 6": "Flickor (A-E)",
        "Unnamed: 7": "Pojkar (A-E)",
        "Unnamed: 8": "Totalt (poäng)",
        "Unnamed: 9": "Flickor (Poäng)",
        "Unnamed: 10": "Pojkar (poäng)"
    },
    axis=1,
)
df_math_rename
# Out:
#     Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga       106766         51548        55218         89.1
# 9   Riket    Kommunal        84163         40386        43777         88.1
# 10  Riket     Enskild        22553         11137        11416         92.9
# 11  Riket  Skolverket           50            25           25         ~100
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           88.7         89.5           11.9            11.8             12
# 9           87.7         88.5           11.6            11.5           11.7
# 10          92.2         93.5             13            12.8           13.1
# 11          ~100         ~100           14.1            13.5           14.7

# %%
df_math_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 8 to 11
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plats            4 non-null      object
#  1   Huvudman         4 non-null      object
#  2   Totalt (A-F)     4 non-null      object
#  3   Flickor (A-F)    4 non-null      object
#  4   Pojkar (A-F)     4 non-null      object
#  5   Totalt (A-E)     4 non-null      object
#  6   Flickor (A-E)    4 non-null      object
#  7   Pojkar (A-E)     4 non-null      object
#  8   Totalt (poäng)   4 non-null      object
#  9   Flickor (Poäng)  4 non-null      object
#  10  Pojkar (poäng)   4 non-null      object
# dtypes: object(11)
# memory usage: 484.0+ bytes

# %%
df_math_rename.columns
# Out:
# Index(['Plats', 'Huvudman', 'Totalt (A-F)', 'Flickor (A-F)', 'Pojkar (A-F)',
#        'Totalt (A-E)', 'Flickor (A-E)', 'Pojkar (A-E)', 'Totalt (poäng)',
#        'Flickor (Poäng)', 'Pojkar (poäng)'],
#       dtype='object')

# %%
df_math_rename["Totalt (A-F)"] = df_math_rename["Totalt (A-F)"].astype(float)

df_math_rename
# Out:
#     Plats    Huvudman  Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga      106766.0         51548        55218         89.1
# 9   Riket    Kommunal       84163.0         40386        43777         88.1
# 10  Riket     Enskild       22553.0         11137        11416         92.9
# 11  Riket  Skolverket          50.0            25           25         ~100
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           88.7         89.5           11.9            11.8             12
# 9           87.7         88.5           11.6            11.5           11.7
# 10          92.2         93.5             13            12.8           13.1
# 11          ~100         ~100           14.1            13.5           14.7

# %%
df_math_rename["Totalt (A-E)"]
# Out:
# 8     89.1
# 9     88.1
# 10    92.9
# 11    ~100
# Name: Totalt (A-E), dtype: object

# %%
df_math_samtliga = df_math_rename.query("Huvudman == 'Samtliga'")
df_math_samtliga["Totalt (A-F)"]
# Out:
# 8    106766.0
# Name: Totalt (A-F), dtype: float64

# %%
df_andel = df_math_samtliga["Totalt (A-F)"] * (1 - (df_math_samtliga["Totalt (A-E)"] / 100))
df_andel = df_andel.astype(int)
df_andel
# Out:
# 8    11637
# dtype: int64

# %%
df_math_rename
# Out:
#     Plats    Huvudman  Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga      106766.0         51548        55218         89.1
# 9   Riket    Kommunal       84163.0         40386        43777         88.1
# 10  Riket     Enskild       22553.0         11137        11416         92.9
# 11  Riket  Skolverket          50.0            25           25         ~100
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           88.7         89.5           11.9            11.8             12
# 9           87.7         88.5           11.6            11.5           11.7
# 10          92.2         93.5             13            12.8           13.1
# 11          ~100         ~100           14.1            13.5           14.7

# %%
df_math_rename["Totalt (poäng)"] = df_math_rename["Totalt (poäng)"].astype(float)

df_math_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 8 to 11
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plats            4 non-null      object
#  1   Huvudman         4 non-null      object
#  2   Totalt (A-F)     4 non-null      float64
#  3   Flickor (A-F)    4 non-null      object
#  4   Pojkar (A-F)     4 non-null      object
#  5   Totalt (A-E)     4 non-null      object
#  6   Flickor (A-E)    4 non-null      object
#  7   Pojkar (A-E)     4 non-null      object
#  8   Totalt (poäng)   4 non-null      float64
#  9   Flickor (Poäng)  4 non-null      object
#  10  Pojkar (poäng)   4 non-null      object
# dtypes: float64(2), object(9)
# memory usage: 484.0+ bytes

# %%
df_poäng = df_math_rename[["Huvudman", "Totalt (poäng)"]]
# Out:
#       Huvudman  Totalt (poäng)
# 8     Samtliga            11.9
# 9     Kommunal            11.6
# 10     Enskild            13.0
# 11  Skolverket            14.1

# %%
df_svenska = pd.read_excel(data_file, sheet_name="Svenska")
df_svenska_rename = df_svenska.tail(4).rename(
    {
        "Unnamed: 0": "Plats",
        "Unnamed: 1": "Huvudman",
        "Unnamed: 2": "Totalt (A-F)",
        "Unnamed: 3": "Flickor (A-F)",
        "Unnamed: 4": "Pojkar (A-F)",
        "Unnamed: 5": "Totalt (A-E)",
        "Unnamed: 6": "Flickor (A-E)",
        "Unnamed: 7": "Pojkar (A-E)",
        "Unnamed: 8": "Totalt (poäng)",
        "Unnamed: 9": "Flickor (Poäng)",
        "Unnamed: 10": "Pojkar (poäng)"
    },
    axis=1,
)

# %%
df_svenska_rename
# Out:
#     Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga        93225         45800        47425         96.1
# 9   Riket    Kommunal        72771         35484        37287         95.7
# 10  Riket     Enskild        20414         10297        10117         97.6
# 11  Riket  Skolverket           40            19           21          100
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           97.9         94.4           13.6            14.5           12.7
# 9           97.6         93.8           13.3            14.3           12.4
# 10          98.7         96.6           14.4            15.2           13.5
# 11           100          100             15            15.9           14.2

# %%
df_math_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 8 to 11
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plats            4 non-null      object
#  1   Huvudman         4 non-null      object
#  2   Totalt (A-F)     4 non-null      float64
#  3   Flickor (A-F)    4 non-null      object
#  4   Pojkar (A-F)     4 non-null      object
#  5   Totalt (A-E)     4 non-null      object
#  6   Flickor (A-E)    4 non-null      object
#  7   Pojkar (A-E)     4 non-null      object
#  8   Totalt (poäng)   4 non-null      float64
#  9   Flickor (Poäng)  4 non-null      object
#  10  Pojkar (poäng)   4 non-null      object
# dtypes: float64(2), object(9)
# memory usage: 484.0+ bytes

# %%
df_engelska_rename = df_rename
df_engelska_rename
# Out:
#     Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga       106941         51864        55077           97
# 9   Riket    Kommunal        84310         40675        43635         96.6
# 10  Riket     Enskild        22582         11165        11417         98.7
# 11  Riket  Skolverket           49            24           25          100
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           97.1           97           15.7            15.8           15.7
# 9           96.6         96.6           15.4            15.5           15.4
# 10          98.8         98.7           16.9              17           16.8
# 11           100          100           18.5            18.9           18.2

# %%
df_svenska_andraspråk = pd.read_excel(data_file,sheet_name="Svenska som andraspråk")
df_cleaned_svenska_andraspråk = df_svenska_andraspråk.tail(4).rename(
    {
        "Unnamed: 0": "Plats",
        "Unnamed: 1": "Huvudman",
        "Unnamed: 2": "Totalt (A-F)",
        "Unnamed: 3": "Flickor (A-F)",
        "Unnamed: 4": "Pojkar (A-F)",
        "Unnamed: 5": "Totalt (A-E)",
        "Unnamed: 6": "Flickor (A-E)",
        "Unnamed: 7": "Pojkar (A-E)",
        "Unnamed: 8": "Totalt (poäng)",
        "Unnamed: 9": "Flickor (Poäng)",
        "Unnamed: 10": "Pojkar (poäng)"
    },
    axis=1,
)

# %%
df_cleaned_svenska_andraspråk
# Out:
#     Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 8   Riket    Samtliga        14092          6447         7645         77.7
# 9   Riket    Kommunal        11963          5495         6468         75.9
# 10  Riket     Enskild         2122           949         1173         87.7
# 11  Riket  Skolverket           ..            ..           ..           ..
#
#    Flickor (A-E) Pojkar (A-E) Totalt (poäng) Flickor (Poäng) Pojkar (poäng)
# 8           81.6         74.3            9.4            10.2            8.7
# 9             80         72.4              9             9.9            8.3
# 10          90.9         85.2           11.1              12           10.4
# 11            ..           ..             ..              ..             ..

# %%
poäng_svenska_andraspråk = df_cleaned_svenska_andraspråk.query("Huvudman == 'Samtliga'")
poäng_svenska_andraspråk

poäng_engelska = df_engelska_rename.query("Huvudman == 'Samtliga'")
poäng_svenska = df_svenska_rename.query("Huvudman == 'Samtliga'")
poäng_math = df_math_rename.query("Huvudman == 'Samtliga'")
poäng_engelska = poäng_engelska["Totalt (poäng)"].values[0]
poäng_svenska = poäng_svenska["Totalt (poäng)"].values[0]
poäng_math = poäng_math["Totalt (poäng)"].values[0]
poäng_svenska_andraspråk = poäng_svenska_andraspråk["Totalt (poäng)"].values[0]

# %%
poäng = [poäng_math, poäng_engelska,poäng_svenska,poäng_svenska_andraspråk]
ämne = ["Matematik", "Engelska", "Svenska", "Svenska som andraspråk"]
poäng
# Out:
# [np.float64(11.9), 15.7, 13.6, 9.4]

# %%
import matplotlib.pyplot as plt
plt.bar(ämne, poäng)
plt.xticks(rotation = 90);
